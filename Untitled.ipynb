# %%
from PIL import Image

# %%
import cv2

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
def order_points(pts):
	# initialzie a list of coordinates that will be ordered
	# such that the first entry in the list is the top-left,
	# the second entry is the top-right, the third is the
	# bottom-right, and the fourth is the bottom-left
	rect = np.zeros((4, 2), dtype = "float32")
	# the top-left point will have the smallest sum, whereas
	# the bottom-right point will have the largest sum
	s = pts.sum(axis = 1)
	rect[0] = pts[np.argmin(s)]
	rect[2] = pts[np.argmax(s)]
	# now, compute the difference between the points, the
	# top-right point will have the smallest difference,
	# whereas the bottom-left will have the largest difference
	diff = np.diff(pts, axis = 1)
	rect[1] = pts[np.argmin(diff)]
	rect[3] = pts[np.argmax(diff)]
	# return the ordered coordinates
	return rect

# %%
def four_point_transform(image, pts):
	# obtain a consistent order of the points and unpack them
	# individually
	rect = order_points(pts)
	(tl, tr, br, bl) = rect
	# compute the width of the new image, which will be the
	# maximum distance between bottom-right and bottom-left
	# x-coordiates or the top-right and top-left x-coordinates
	widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
	widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
	maxWidth = max(int(widthA), int(widthB))
	# compute the height of the new image, which will be the
	# maximum distance between the top-right and bottom-right
	# y-coordinates or the top-left and bottom-left y-coordinates
	heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
	heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
	maxHeight = max(int(heightA), int(heightB))
	# now that we have the dimensions of the new image, construct
	# the set of destination points to obtain a "birds eye view",
	# (i.e. top-down view) of the image, again specifying points
	# in the top-left, top-right, bottom-right, and bottom-left
	# order
	dst = np.array([
		[0, 0],
		[maxWidth - 1, 0],
		[maxWidth - 1, maxHeight - 1],
		[0, maxHeight - 1]], dtype = "float32")
	# compute the perspective transform matrix and then apply it
	M = cv2.getPerspectiveTransform(rect, dst)
	warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))
	# return the warped image
	return warped

# %%
img_path = r'C:\Users\James.Goulding\PycharmProjects\PokemonProject\Resources\farOffBlitzle.jpeg'
img = cv2.imread(img_path)

if img is None:
    print('No image found at', img_path)
else:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (7, 7), 0)

    thresh = cv2.adaptiveThreshold(blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                   cv2.THRESH_BINARY_INV, 205, 1)
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)


filtered = []
for c in contours:
    area = cv2.contourArea(c)
    print(f"Contour area: {area}")
    if area > 10000:
        filtered.append(c)

xArea = 0
x = None
for f in filtered:
    area = cv2.contourArea(f)
    if area > xArea:
        x = f
        print(f"Old largest area: {xArea}")
        xArea = area
        print(f"New largest contour with area: {xArea}")

filtered = [x]
print(f"{filtered[0]}")
rect = cv2.minAreaRect(filtered[0])
box = cv2.boxPoints(rect)
print(f"{rect[0]}")
print(f"{box}")
pts = order_points(box)
wrapped_img = four_point_transform(img.copy(), pts)
plt.imshow(wrapped_img)

# Load the image
img = wrapped_img

# Calculate midpoints
height = img.shape[0]
width = img.shape[1]
bottom_left_corner = img[height//2:, :width//2]

# Display the bottom-left corner
plt.imshow(bottom_left_corner)
plt.show()
# Out:
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 4.5
# Contour area: 5.0
# Contour area: 1.0
# Contour area: 2.0
# Contour area: 2.0
# Contour area: 6.0
# Contour area: 10.0
# Contour area: 8.0
# Contour area: 18.0
# Contour area: 45.0
# Contour area: 39.5
# Contour area: 27.0
# Contour area: 10.5
# Contour area: 52.0
# Contour area: 59.5
# Contour area: 23.0
# Contour area: 34.5
# Contour area: 30.5
# Contour area: 89.0
# Contour area: 64.5
# Contour area: 99.5
# Contour area: 46.5
# Contour area: 80.5
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 13.0
# Contour area: 3.5
# Contour area: 3.5
# Contour area: 55.5
# Contour area: 138.5
# Contour area: 114.5
# Contour area: 167.0
# Contour area: 14.0
# Contour area: 111.5
# Contour area: 206.5
# Contour area: 38.0
# Contour area: 79.5
# Contour area: 89.0
# Contour area: 54.5
# Contour area: 0.0
# Contour area: 8.5
# Contour area: 316.5
# Contour area: 170.0
# Contour area: 33.0
# Contour area: 2.0
# Contour area: 89.5
# Contour area: 1.0
# Contour area: 254.0
# Contour area: 66.5
# Contour area: 1.0
# Contour area: 1.0
# Contour area: 291.0
# Contour area: 59.0
# Contour area: 44.0
# Contour area: 3.5
# Contour area: 3.5
# Contour area: 450.5
# Contour area: 2.5
# Contour area: 2.5
# Contour area: 5.0
# Contour area: 60.0
# Contour area: 122.0
# Contour area: 35.0
# Contour area: 233.0
# Contour area: 16.0
# Contour area: 0.0
# Contour area: 2.5
# Contour area: 974.5
# Contour area: 17.5
# Contour area: 6.5
# Contour area: 7.5
# Contour area: 623.5
# Contour area: 422.5
# Contour area: 118.0
# Contour area: 13.0
# Contour area: 745.0
# Contour area: 227.5
# Contour area: 2.0
# Contour area: 1697.0
# Contour area: 95.5
# Contour area: 278.5
# Contour area: 90.5
# Contour area: 24.0
# Contour area: 493.5
# Contour area: 18.5
# Contour area: 117.0
# Contour area: 10.5
# Contour area: 0.0
# Contour area: 32.5
# Contour area: 80.0
# Contour area: 38.5
# Contour area: 640.5
# Contour area: 7.5
# Contour area: 438.5
# Contour area: 0.0
# Contour area: 3.0
# Contour area: 84.5
# Contour area: 167.5
# Contour area: 538.5
# Contour area: 134.0
# Contour area: 1.5
# Contour area: 559.5
# Contour area: 4.5
# Contour area: 5.5
# Contour area: 19.5
# Contour area: 19.0
# Contour area: 0.5
# Contour area: 1338.5
# Contour area: 1160.5
# Contour area: 1224.0
# Contour area: 2141.0
# Contour area: 11.5
# Contour area: 99.5
# Contour area: 55.5
# Contour area: 26.0
# Contour area: 14.5
# Contour area: 0.0
# Contour area: 12.5
# Contour area: 32.5
# Contour area: 30.0
# Contour area: 1237.0
# Contour area: 29.5
# Contour area: 255.0
# Contour area: 160.0
# Contour area: 85.5
# Contour area: 76.0
# Contour area: 23.0
# Contour area: 984.5
# Contour area: 1315.0
# Contour area: 17.5
# Contour area: 175.5
# Contour area: 23.0
# Contour area: 38.0
# Contour area: 3.0
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 909.0
# Contour area: 227.5
# Contour area: 1140.0
# Contour area: 51.5
# Contour area: 173.0
# Contour area: 10.5
# Contour area: 355.0
# Contour area: 0.5
# Contour area: 8.5
# Contour area: 36.0
# Contour area: 2132.5
# Contour area: 30.5
# Contour area: 78.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 28.5
# Contour area: 1305.5
# Contour area: 1734.5
# Contour area: 678.5
# Contour area: 42.5
# Contour area: 117.5
# Contour area: 612.5
# Contour area: 242.5
# Contour area: 4.5
# Contour area: 3.5
# Contour area: 4.0
# Contour area: 185.0
# Contour area: 166.0
# Contour area: 9.5
# Contour area: 16.5
# Contour area: 31.5
# Contour area: 97.5
# Contour area: 0.5
# Contour area: 2.0
# Contour area: 219.0
# Contour area: 153.0
# Contour area: 371.0
# Contour area: 1638.5
# Contour area: 901.0
# Contour area: 12.0
# Contour area: 7.0
# Contour area: 2.5
# Contour area: 31.5
# Contour area: 94.5
# Contour area: 21.5
# Contour area: 8.5
# Contour area: 87.0
# Contour area: 64.5
# Contour area: 32.0
# Contour area: 4.5
# Contour area: 17.0
# Contour area: 162.5
# Contour area: 147.5
# Contour area: 58.0
# Contour area: 2284.0
# Contour area: 315.5
# Contour area: 225.5
# Contour area: 137.0
# Contour area: 185.0
# Contour area: 179.0
# Contour area: 380.0
# Contour area: 28.5
# Contour area: 2119.5
# Contour area: 953.5
# Contour area: 149.0
# Contour area: 88.5
# Contour area: 2255.5
# Contour area: 0.0
# Contour area: 24.0
# Contour area: 774.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 131.5
# Contour area: 199.5
# Contour area: 311.0
# Contour area: 432.5
# Contour area: 59.5
# Contour area: 6.0
# Contour area: 155.0
# Contour area: 258.5
# Contour area: 48.0
# Contour area: 77.5
# Contour area: 328.5
# Contour area: 6.0
# Contour area: 0.5
# Contour area: 1778.5
# Contour area: 830.0
# Contour area: 523.0
# Contour area: 60.5
# Contour area: 29.5
# Contour area: 75.0
# Contour area: 24.0
# Contour area: 6.0
# Contour area: 9.0
# Contour area: 248.5
# Contour area: 3905.5
# Contour area: 1040.5
# Contour area: 0.0
# Contour area: 33.0
# Contour area: 410.5
# Contour area: 98.5
# Contour area: 359.5
# Contour area: 121.0
# Contour area: 47.5
# Contour area: 175.0
# Contour area: 4.5
# Contour area: 96.0
# Contour area: 219.5
# Contour area: 110.5
# Contour area: 2890.0
# Contour area: 208.5
# Contour area: 96.5
# Contour area: 542.0
# Contour area: 13.0
# Contour area: 492.5
# Contour area: 20.5
# Contour area: 2777.0
# Contour area: 61.0
# Contour area: 89.0
# Contour area: 493.5
# Contour area: 423.5
# Contour area: 133.5
# Contour area: 231.0
# Contour area: 86.0
# Contour area: 993.0
# Contour area: 187.0
# Contour area: 337.0
# Contour area: 2042.5
# Contour area: 384.5
# Contour area: 99.5
# Contour area: 0.0
# Contour area: 229.5
# Contour area: 22.5
# Contour area: 201.0
# Contour area: 259.5
# Contour area: 222.0
# Contour area: 94.0
# Contour area: 9.0
# Contour area: 404.5
# Contour area: 220.5
# Contour area: 367.5
# Contour area: 67.5
# Contour area: 0.0
# Contour area: 112.5
# Contour area: 645.5
# Contour area: 302.0
# Contour area: 348.5
# Contour area: 204.0
# Contour area: 112.5
# Contour area: 400.5
# Contour area: 2058.0
# Contour area: 22.5
# Contour area: 6.0
# Contour area: 144.0
# Contour area: 3169.0
# Contour area: 376.0
# Contour area: 14.5
# Contour area: 113.0
# Contour area: 72.5
# Contour area: 267.5
# Contour area: 59.0
# Contour area: 50.5
# Contour area: 0.5
# Contour area: 1695.0
# Contour area: 149.0
# Contour area: 6.0
# Contour area: 47.0
# Contour area: 155.0
# Contour area: 164.0
# Contour area: 0.0
# Contour area: 594.5
# Contour area: 101.5
# Contour area: 121.5
# Contour area: 258.5
# Contour area: 0.0
# Contour area: 2916.0
# Contour area: 13.5
# Contour area: 178.0
# Contour area: 44.0
# Contour area: 59.0
# Contour area: 8.5
# Contour area: 5.0
# Contour area: 16.5
# Contour area: 67.5
# Contour area: 777.0
# Contour area: 323.0
# Contour area: 0.5
# Contour area: 29.0
# Contour area: 4.5
# Contour area: 1.5
# Contour area: 4.0
# Contour area: 10.0
# Contour area: 15.0
# Contour area: 6.0
# Contour area: 79.0
# Contour area: 0.0
# Contour area: 22.5
# Contour area: 138.0
# Contour area: 993.5
# Contour area: 57.5
# Contour area: 622.0
# Contour area: 35.0
# Contour area: 4341.5
# Contour area: 180.5
# Contour area: 3.0
# Contour area: 89.0
# Contour area: 7.5
# Contour area: 184.5
# Contour area: 152.0
# Contour area: 190.5
# Contour area: 2053.5
# Contour area: 21.5
# Contour area: 0.5
# Contour area: 96.0
# Contour area: 16.5
# Contour area: 29.5
# Contour area: 203.5
# Contour area: 177.0
# Contour area: 2598.5
# Contour area: 32.5
# Contour area: 26.0
# Contour area: 181.0
# Contour area: 97.5
# Contour area: 0.0
# Contour area: 51.5
# Contour area: 4213.5
# Contour area: 3.5
# Contour area: 770.0
# Contour area: 199.0
# Contour area: 28.0
# Contour area: 50.5
# Contour area: 32.0
# Contour area: 27.0
# Contour area: 6.5
# Contour area: 1087.5
# Contour area: 87.0
# Contour area: 141.0
# Contour area: 65.5
# Contour area: 387.5
# Contour area: 0.0
# Contour area: 71.0
# Contour area: 101.5
# Contour area: 2319.0
# Contour area: 63.0
# Contour area: 115.0
# Contour area: 8.5
# Contour area: 246.5
# Contour area: 263.5
# Contour area: 58.0
# Contour area: 2957.5
# Contour area: 20.5
# Contour area: 0.0
# Contour area: 17.0
# Contour area: 286.5
# Contour area: 659.5
# Contour area: 18.5
# Contour area: 20.0
# Contour area: 2.0
# Contour area: 5.5
# Contour area: 161.0
# Contour area: 625.5
# Contour area: 93.0
# Contour area: 511.5
# Contour area: 33.5
# Contour area: 1445.0
# Contour area: 1090.0
# Contour area: 773.5
# Contour area: 58.5
# Contour area: 145.5
# Contour area: 13.5
# Contour area: 104.5
# Contour area: 1058.5
# Contour area: 330.5
# Contour area: 10.0
# Contour area: 41.0
# Contour area: 327.0
# Contour area: 102.0
# Contour area: 423.0
# Contour area: 60.5
# Contour area: 144.5
# Contour area: 141.5
# Contour area: 92.5
# Contour area: 319.5
# Contour area: 289.0
# Contour area: 3.0
# Contour area: 557.0
# Contour area: 87.5
# Contour area: 1769.0
# Contour area: 179.5
# Contour area: 410.0
# Contour area: 193.0
# Contour area: 572.5
# Contour area: 44.5
# Contour area: 1769.0
# Contour area: 2.0
# Contour area: 1879.0
# Contour area: 21.5
# Contour area: 121.5
# Contour area: 31.0
# Contour area: 255.0
# Contour area: 1.0
# Contour area: 11.0
# Contour area: 6.0
# Contour area: 2.0
# Contour area: 16.0
# Contour area: 37.5
# Contour area: 47.0
# Contour area: 569.5
# Contour area: 1.5
# Contour area: 1592.5
# Contour area: 7.5
# Contour area: 26.5
# Contour area: 465.5
# Contour area: 1951.0
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 1.5
# Contour area: 128.5
# Contour area: 46.5
# Contour area: 63.5
# Contour area: 71.5
# Contour area: 86.5
# Contour area: 0.0
# Contour area: 1178.5
# Contour area: 166.0
# Contour area: 37.0
# Contour area: 411.5
# Contour area: 0.5
# Contour area: 203.5
# Contour area: 0.0
# Contour area: 86.0
# Contour area: 169.0
# Contour area: 1151.5
# Contour area: 2621.5
# Contour area: 21.0
# Contour area: 187.5
# Contour area: 409.0
# Contour area: 199.5
# Contour area: 105.5
# Contour area: 7.0
# Contour area: 6.0
# Contour area: 2601.5
# Contour area: 290.0
# Contour area: 160.0
# Contour area: 31.0
# Contour area: 34.5
# Contour area: 416.0
# Contour area: 20.5
# Contour area: 129.5
# Contour area: 742.0
# Contour area: 742.0
# Contour area: 13.5
# Contour area: 3440.0
# Contour area: 603.5
# Contour area: 69.5
# Contour area: 2072.0
# Contour area: 307.5
# Contour area: 138.5
# Contour area: 6.5
# Contour area: 26.0
# Contour area: 85.5
# Contour area: 62.5
# Contour area: 51.0
# Contour area: 3.0
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 347.5
# Contour area: 518.0
# Contour area: 30.5
# Contour area: 71.0
# Contour area: 310.0
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 210.0
# Contour area: 409.0
# Contour area: 9.5
# Contour area: 47.5
# Contour area: 53.5
# Contour area: 1049.5
# Contour area: 14.0
# Contour area: 91.0
# Contour area: 236.0
# Contour area: 480.0
# Contour area: 20.0
# Contour area: 1.0
# Contour area: 78.0
# Contour area: 88.5
# Contour area: 52.0
# Contour area: 236.0
# Contour area: 33.5
# Contour area: 730.5
# Contour area: 635.0
# Contour area: 752.0
# Contour area: 34.5
# Contour area: 0.0
# Contour area: 54.0
# Contour area: 2832.0
# Contour area: 0.0
# Contour area: 2773.5
# Contour area: 17.5
# Contour area: 165.0
# Contour area: 1.0
# Contour area: 26.5
# Contour area: 87.5
# Contour area: 63.5
# Contour area: 97.5
# Contour area: 1540.5
# Contour area: 283.5
# Contour area: 262.0
# Contour area: 116.0
# Contour area: 7.5
# Contour area: 85.5
# Contour area: 87.5
# Contour area: 66.5
# Contour area: 24.5
# Contour area: 9.5
# Contour area: 211.5
# Contour area: 1.5
# Contour area: 84.0
# Contour area: 155.0
# Contour area: 301.5
# Contour area: 18.0
# Contour area: 178.0
# Contour area: 174.0
# Contour area: 692.0
# Contour area: 18.0
# Contour area: 544.5
# Contour area: 197.0
# Contour area: 40.0
# Contour area: 31.0
# Contour area: 3245.0
# Contour area: 25.0
# Contour area: 54.0
# Contour area: 100.5
# Contour area: 21.5
# Contour area: 59.5
# Contour area: 45.0
# Contour area: 6.5
# Contour area: 2.5
# Contour area: 22.0
# Contour area: 421.5
# Contour area: 3213.5
# Contour area: 37.5
# Contour area: 71.0
# Contour area: 28.0
# Contour area: 11.5
# Contour area: 33.5
# Contour area: 38.5
# Contour area: 1491.0
# Contour area: 18.0
# Contour area: 68.5
# Contour area: 19.5
# Contour area: 82.5
# Contour area: 14.0
# Contour area: 17.0
# Contour area: 5.5
# Contour area: 1329.5
# Contour area: 30.5
# Contour area: 2.5
# Contour area: 760.5
# Contour area: 99.5
# Contour area: 1080.0
# Contour area: 40.5
# Contour area: 0.0
# Contour area: 36.5
# Contour area: 9.0
# Contour area: 34.0
# Contour area: 243.0
# Contour area: 64.5
# Contour area: 118.0
# Contour area: 215.5
# Contour area: 7.0
# Contour area: 18.5
# Contour area: 27.0
# Contour area: 21.0
# Contour area: 49.5
# Contour area: 28.5
# Contour area: 26.5
# Contour area: 468.0
# Contour area: 131.0
# Contour area: 1238.5
# Contour area: 636.5
# Contour area: 23.0
# Contour area: 63.5
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 4.5
# Contour area: 0.0
# Contour area: 3.0
# Contour area: 176.5
# Contour area: 10.5
# Contour area: 3358.5
# Contour area: 579.5
# Contour area: 130.0
# Contour area: 174.0
# Contour area: 381.5
# Contour area: 311.0
# Contour area: 21.0
# Contour area: 518.0
# Contour area: 103.0
# Contour area: 0.0
# Contour area: 1141.5
# Contour area: 2.5
# Contour area: 208.0
# Contour area: 11.0
# Contour area: 40.0
# Contour area: 104.5
# Contour area: 2303.5
# Contour area: 325.0
# Contour area: 156.0
# Contour area: 282.5
# Contour area: 152.5
# Contour area: 69.0
# Contour area: 87.5
# Contour area: 13.5
# Contour area: 59.0
# Contour area: 34.0
# Contour area: 148.0
# Contour area: 17.5
# Contour area: 141.5
# Contour area: 0.0
# Contour area: 8.0
# Contour area: 0.0
# Contour area: 12.0
# Contour area: 30.0
# Contour area: 13.5
# Contour area: 412.5
# Contour area: 45.0
# Contour area: 1997.0
# Contour area: 8.5
# Contour area: 175.0
# Contour area: 28.5
# Contour area: 30.0
# Contour area: 715.0
# Contour area: 153.5
# Contour area: 1452.5
# Contour area: 41.5
# Contour area: 37.0
# Contour area: 137.5
# Contour area: 36.5
# Contour area: 7.0
# Contour area: 30.0
# Contour area: 24.5
# Contour area: 20.5
# Contour area: 230.5
# Contour area: 3.0
# Contour area: 146.0
# Contour area: 168.5
# Contour area: 0.0
# Contour area: 264.0
# Contour area: 267.5
# Contour area: 126.5
# Contour area: 43.0
# Contour area: 132.0
# Contour area: 719.5
# Contour area: 9.0
# Contour area: 674.0
# Contour area: 61.0
# Contour area: 443.0
# Contour area: 3737.0
# Contour area: 13.0
# Contour area: 334.0
# Contour area: 83.0
# Contour area: 181.0
# Contour area: 174.0
# Contour area: 438.0
# Contour area: 238.5
# Contour area: 65.5
# Contour area: 8.5
# Contour area: 43.5
# Contour area: 286.0
# Contour area: 107.0
# Contour area: 114.5
# Contour area: 7.5
# Contour area: 2346.0
# Contour area: 372.5
# Contour area: 225.0
# Contour area: 14.0
# Contour area: 102.0
# Contour area: 8.0
# Contour area: 104.0
# Contour area: 1373.0
# Contour area: 307.0
# Contour area: 74.5
# Contour area: 160.5
# Contour area: 284.5
# Contour area: 158.0
# Contour area: 0.0
# Contour area: 2.0
# Contour area: 155.0
# Contour area: 134.5
# Contour area: 62.5
# Contour area: 8.5
# Contour area: 6.5
# Contour area: 16.5
# Contour area: 84.5
# Contour area: 4.0
# Contour area: 5.0
# Contour area: 80.0
# Contour area: 149.5
# Contour area: 466.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 6242.0
# Contour area: 15.5
# Contour area: 68.5
# Contour area: 1.5
# Contour area: 37.5
# Contour area: 745.0
# Contour area: 192.5
# Contour area: 2592.5
# Contour area: 0.0
# Contour area: 514.5
# Contour area: 21.0
# Contour area: 129.5
# Contour area: 233.5
# Contour area: 2925.0
# Contour area: 13.5
# Contour area: 268.5
# Contour area: 244.0
# Contour area: 1766.0
# Contour area: 25713.0
# Contour area: 71.5
# Contour area: 2764.0
# Contour area: 851.5
# Contour area: 65.0
# Contour area: 101.5
# Contour area: 3.0
# Contour area: 1466.0
# Contour area: 25.5
# Contour area: 134.0
# Contour area: 0.0
# Contour area: 28.5
# Contour area: 96.5
# Contour area: 55.5
# Contour area: 17.5
# Contour area: 0.0
# Contour area: 66.0
# Contour area: 13.5
# Contour area: 20.0
# Contour area: 416.0
# Contour area: 5.0
# Contour area: 198.0
# Contour area: 0.5
# Contour area: 27.5
# Contour area: 10.5
# Contour area: 119.0
# Contour area: 1.0
# Contour area: 7.0
# Contour area: 1106.5
# Contour area: 301.0
# Contour area: 29.0
# Contour area: 65.5
# Contour area: 98.0
# Contour area: 112.5
# Contour area: 14.5
# Contour area: 23.5
# Contour area: 923.5
# Contour area: 1357.5
# Contour area: 52.5
# Contour area: 38.5
# Contour area: 31.5
# Contour area: 904.5
# Contour area: 36.0
# Contour area: 75.0
# Contour area: 0.0
# Contour area: 10.5
# Contour area: 11.5
# Contour area: 18.5
# Contour area: 65.0
# Contour area: 470.0
# Contour area: 45.0
# Contour area: 5156.0
# Contour area: 60.0
# Contour area: 24.5
# Contour area: 2497.0
# Contour area: 9.0
# Contour area: 100.5
# Contour area: 2.5
# Contour area: 76.0
# Contour area: 25.0
# Contour area: 16.0
# Contour area: 95.5
# Contour area: 1701.0
# Contour area: 72.0
# Contour area: 70.5
# Contour area: 69.5
# Contour area: 20.0
# Contour area: 20.0
# Contour area: 216.5
# Contour area: 245.0
# Contour area: 34.0
# Contour area: 30.5
# Contour area: 11.0
# Contour area: 117.5
# Contour area: 1679.5
# Contour area: 207.0
# Contour area: 609.5
# Contour area: 186.0
# Contour area: 17.5
# Contour area: 2022.0
# Contour area: 401.5
# Contour area: 511.5
# Contour area: 42.0
# Contour area: 2.0
# Contour area: 270.0
# Contour area: 24.5
# Contour area: 586.5
# Contour area: 367.0
# Contour area: 155.0
# Contour area: 132.5
# Contour area: 8.5
# Contour area: 763.0
# Contour area: 281.0
# Contour area: 148.0
# Contour area: 2.0
# Contour area: 29.5
# Contour area: 2.0
# Contour area: 3.5
# Contour area: 1.5
# Contour area: 491.0
# Contour area: 119.0
# Contour area: 1182.0
# Contour area: 18.0
# Contour area: 34.0
# Contour area: 7.0
# Contour area: 21.5
# Contour area: 0.5
# Contour area: 55.0
# Contour area: 932.0
# Contour area: 35.5
# Contour area: 70.0
# Contour area: 1093.0
# Contour area: 407.0
# Contour area: 5.5
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 971.5
# Contour area: 213.5
# Contour area: 619.0
# Contour area: 1869.0
# Contour area: 873.0
# Contour area: 12.0
# Contour area: 29.0
# Contour area: 139.0
# Contour area: 86.5
# Contour area: 191.5
# Contour area: 291.5
# Contour area: 121.0
# Contour area: 8.5
# Contour area: 5.0
# Contour area: 59.5
# Contour area: 21.5
# Contour area: 27.0
# Contour area: 8.5
# Contour area: 98.5
# Contour area: 217.5
# Contour area: 91.0
# Contour area: 3.5
# Contour area: 2235.0
# Contour area: 91.0
# Contour area: 322.5
# Contour area: 343.0
# Contour area: 89.0
# Contour area: 35.0
# Contour area: 56.5
# Contour area: 736.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 1210.5
# Contour area: 487.0
# Contour area: 0.0
# Contour area: 2.0
# Contour area: 1.0
# Contour area: 27.0
# Contour area: 12.0
# Contour area: 54.5
# Contour area: 11.0
# Contour area: 4035.0
# Contour area: 130.5
# Contour area: 2384.5
# Contour area: 0.0
# Contour area: 7.0
# Contour area: 9.0
# Contour area: 167.0
# Contour area: 2.5
# Contour area: 39.0
# Contour area: 36.0
# Contour area: 253.5
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 1067.5
# Contour area: 3971.5
# Contour area: 97.5
# Contour area: 201.5
# Contour area: 1888.0
# Contour area: 15.5
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 1.0
# Contour area: 1213.5
# Contour area: 0.5
# Contour area: 1.5
# Contour area: 245.5
# Contour area: 0.0
# Contour area: 26.5
# Contour area: 11.5
# Contour area: 54.5
# Contour area: 47.0
# Contour area: 1504.5
# Contour area: 15.5
# Contour area: 249.5
# Contour area: 21.0
# Contour area: 9.5
# Contour area: 111.0
# Contour area: 144.5
# Contour area: 10.5
# Contour area: 6.5
# Contour area: 120.5
# Contour area: 0.0
# Contour area: 132.0
# Contour area: 88.5
# Contour area: 70.5
# Contour area: 11.5
# Contour area: 48.0
# Contour area: 1686.0
# Contour area: 1800.5
# Contour area: 114.5
# Contour area: 0.0
# Contour area: 23.5
# Contour area: 17.0
# Contour area: 5.0
# Contour area: 309.5
# Contour area: 4.5
# Contour area: 5.0
# Contour area: 434.0
# Contour area: 4804.0
# Contour area: 880.0
# Contour area: 90.0
# Contour area: 0.0
# Contour area: 35.0
# Contour area: 135.5
# Contour area: 18.0
# Contour area: 162.5
# Contour area: 92.0
# Contour area: 649.0
# Contour area: 330.0
# Contour area: 3470.0
# Contour area: 211.5
# Contour area: 144.0
# Contour area: 5.5
# Contour area: 65.0
# Contour area: 848.5
# Contour area: 192.0
# Contour area: 5.5
# Contour area: 244.5
# Contour area: 11.0
# Contour area: 265.0
# Contour area: 171.5
# Contour area: 3.0
# Contour area: 24.5
# Contour area: 1371.0
# Contour area: 1516.0
# Contour area: 0.0
# Contour area: 167.0
# Contour area: 1.5
# Contour area: 17.0
# Contour area: 191.5
# Contour area: 100.5
# Contour area: 23.5
# Contour area: 8.0
# Contour area: 113.5
# Contour area: 14.0
# Contour area: 7.5
# Contour area: 159.0
# Contour area: 68.0
# Contour area: 32.5
# Contour area: 456.0
# Contour area: 460.5
# Contour area: 413.5
# Contour area: 18.5
# Contour area: 335.5
# Contour area: 11.0
# Contour area: 40.0
# Contour area: 106.5
# Contour area: 4.5
# Contour area: 132.5
# Contour area: 168.5
# Contour area: 105.5
# Contour area: 2132.5
# Contour area: 3315.5
# Contour area: 84.5
# Contour area: 18.0
# Contour area: 76.5
# Contour area: 8.0
# Contour area: 13.0
# Contour area: 3423.5
# Contour area: 313.0
# Contour area: 9.0
# Contour area: 664.5
# Contour area: 2.5
# Contour area: 210.0
# Contour area: 498.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 129.5
# Contour area: 278.0
# Contour area: 317.5
# Contour area: 185.0
# Contour area: 22.0
# Contour area: 202.0
# Contour area: 241.0
# Contour area: 73.5
# Contour area: 53.0
# Contour area: 33.0
# Contour area: 3.0
# Contour area: 89.0
# Contour area: 173.5
# Contour area: 1.0
# Contour area: 8.5
# Contour area: 375.0
# Contour area: 26.5
# Contour area: 29.5
# Contour area: 7.5
# Contour area: 50.5
# Contour area: 10.0
# Contour area: 1287.5
# Contour area: 1107.0
# Contour area: 56.5
# Contour area: 581.0
# Contour area: 575.5
# Contour area: 284.0
# Contour area: 225.5
# Contour area: 10.5
# Contour area: 10.5
# Contour area: 125.5
# Contour area: 171.0
# Contour area: 150.5
# Contour area: 41.0
# Contour area: 3.5
# Contour area: 380.5
# Contour area: 233.5
# Contour area: 288.0
# Contour area: 0.0
# Contour area: 255.0
# Contour area: 93.5
# Contour area: 1.0
# Contour area: 23.5
# Contour area: 119.5
# Contour area: 365.5
# Contour area: 262.0
# Contour area: 4.0
# Contour area: 32.5
# Contour area: 30.5
# Contour area: 151.0
# Contour area: 26.5
# Contour area: 5.0
# Contour area: 11.0
# Contour area: 100.5
# Contour area: 90.0
# Contour area: 230.5
# Contour area: 0.5
# Contour area: 470.0
# Contour area: 109.5
# Contour area: 1.5
# Contour area: 229.5
# Contour area: 37.5
# Contour area: 81.5
# Contour area: 128.5
# Contour area: 68.5
# Contour area: 14.0
# Contour area: 205.5
# Contour area: 2.0
# Contour area: 36.0
# Contour area: 42.0
# Contour area: 0.0
# Contour area: 25.5
# Contour area: 305.5
# Contour area: 4.5
# Contour area: 14.0
# Contour area: 12.5
# Contour area: 3475.0
# Contour area: 1.5
# Contour area: 671.0
# Contour area: 0.5
# Contour area: 55.0
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 70.5
# Contour area: 38.5
# Contour area: 102.5
# Contour area: 2272.5
# Contour area: 1.0
# Contour area: 715.5
# Contour area: 1839.5
# Contour area: 0.5
# Contour area: 156.0
# Contour area: 41.5
# Contour area: 45.5
# Contour area: 443.5
# Contour area: 127.5
# Contour area: 148.5
# Contour area: 8.0
# Contour area: 335.0
# Contour area: 475.5
# Contour area: 179.0
# Contour area: 278.0
# Contour area: 18.5
# Contour area: 27.5
# Contour area: 18.5
# Contour area: 39.5
# Contour area: 18.0
# Contour area: 102.0
# Contour area: 3.0
# Contour area: 2.0
# Contour area: 60.5
# Contour area: 204.0
# Contour area: 1731.5
# Contour area: 28.0
# Contour area: 8.0
# Contour area: 333.0
# Contour area: 722.5
# Contour area: 46.0
# Contour area: 16.0
# Contour area: 694.5
# Contour area: 52.0
# Contour area: 27.0
# Contour area: 69.0
# Contour area: 32.0
# Contour area: 10.5
# Contour area: 727.0
# Contour area: 43.0
# Contour area: 70.0
# Contour area: 9.0
# Contour area: 23.0
# Contour area: 7.0
# Contour area: 16.0
# Contour area: 0.0
# Contour area: 22.0
# Contour area: 5.0
# Contour area: 59.0
# Contour area: 24.0
# Contour area: 316.5
# Contour area: 25.5
# Contour area: 117.0
# Contour area: 3913.0
# Contour area: 199.5
# Contour area: 4.0
# Contour area: 60.5
# Contour area: 18.5
# Contour area: 992.5
# Contour area: 97.5
# Contour area: 17.0
# Contour area: 0.5
# Contour area: 17.5
# Contour area: 216.0
# Contour area: 397.5
# Contour area: 0.5
# Contour area: 1.5
# Contour area: 288.5
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 10.5
# Contour area: 710.5
# Contour area: 1773.5
# Contour area: 12.0
# Contour area: 383.5
# Contour area: 90.5
# Contour area: 9.0
# Contour area: 67.5
# Contour area: 1176.0
# Contour area: 10.5
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 203.0
# Contour area: 715.0
# Contour area: 0.5
# Contour area: 113.5
# Contour area: 26.5
# Contour area: 152.0
# Contour area: 133.0
# Contour area: 1068.0
# Contour area: 4.0
# Contour area: 222.0
# Contour area: 97.0
# Contour area: 1.0
# Contour area: 359.5
# Contour area: 160.5
# Contour area: 282.5
# Contour area: 85.0
# Contour area: 0.0
# Contour area: 127.5
# Contour area: 1.5
# Contour area: 17.0
# Contour area: 1367.0
# Contour area: 3.0
# Contour area: 634.5
# Contour area: 13.0
# Contour area: 32.0
# Contour area: 82.0
# Contour area: 186.0
# Contour area: 0.0
# Contour area: 90.5
# Contour area: 10.5
# Contour area: 6.5
# Contour area: 36.0
# Contour area: 1240.0
# Contour area: 13.0
# Contour area: 0.5
# Contour area: 70.0
# Contour area: 142.5
# Contour area: 0.0
# Contour area: 18.0
# Contour area: 0.0
# Contour area: 4783.5
# Contour area: 86.5
# Contour area: 1658.5
# Contour area: 140.5
# Contour area: 116.5
# Contour area: 16.0
# Contour area: 34.5
# Contour area: 62.5
# Contour area: 1457.0
# Contour area: 76.5
# Contour area: 7.5
# Contour area: 150.5
# Contour area: 59.0
# Contour area: 69.5
# Contour area: 4190.0
# Contour area: 241.5
# Contour area: 18.5
# Contour area: 193.0
# Contour area: 49.5
# Contour area: 85.0
# Contour area: 504.5
# Contour area: 35.5
# Contour area: 394.0
# Contour area: 1268.5
# Contour area: 1.0
# Contour area: 2245.5
# Contour area: 315.0
# Contour area: 3.0
# Contour area: 262.5
# Contour area: 69.0
# Contour area: 5.5
# Contour area: 4.0
# Contour area: 66.5
# Contour area: 227.5
# Contour area: 2.5
# Contour area: 413.0
# Contour area: 132.0
# Contour area: 13.0
# Contour area: 1017.0
# Contour area: 49.0
# Contour area: 32.5
# Contour area: 29.0
# Contour area: 7.0
# Contour area: 19.5
# Contour area: 103.0
# Contour area: 57.0
# Contour area: 1241.5
# Contour area: 158.5
# Contour area: 6.0
# Contour area: 256.0
# Contour area: 503.0
# Contour area: 21.5
# Contour area: 47.0
# Contour area: 273.0
# Contour area: 13.5
# Contour area: 94.0
# Contour area: 8.5
# Contour area: 1.5
# Contour area: 103.0
# Contour area: 51.0
# Contour area: 21.0
# Contour area: 1843.5
# Contour area: 99.0
# Contour area: 73.5
# Contour area: 258.5
# Contour area: 167.0
# Contour area: 8.5
# Contour area: 30.5
# Contour area: 68.5
# Contour area: 0.0
# Contour area: 5.5
# Contour area: 145.5
# Contour area: 18.5
# Contour area: 14.5
# Contour area: 687.0
# Contour area: 1125.5
# Contour area: 1.5
# Contour area: 13.5
# Contour area: 9.5
# Contour area: 2.5
# Contour area: 24.0
# Contour area: 104.5
# Contour area: 32.0
# Contour area: 47.5
# Contour area: 229.0
# Contour area: 6.0
# Contour area: 41.0
# Contour area: 5.0
# Contour area: 23.5
# Contour area: 96.5
# Contour area: 166.0
# Contour area: 2641.5
# Contour area: 329.0
# Contour area: 652.5
# Contour area: 5.5
# Contour area: 142.0
# Contour area: 47.0
# Contour area: 716.5
# Contour area: 143.0
# Contour area: 17.0
# Contour area: 0.5
# Contour area: 14.5
# Contour area: 26.0
# Contour area: 861.5
# Contour area: 3.0
# Contour area: 41.5
# Contour area: 232.5
# Contour area: 8.0
# Contour area: 2357.5
# Contour area: 92.0
# Contour area: 51.5
# Contour area: 3.5
# Contour area: 1.5
# Contour area: 163.5
# Contour area: 1.5
# Contour area: 27.0
# Contour area: 189.5
# Contour area: 0.5
# Contour area: 1588.5
# Contour area: 441.5
# Contour area: 1546.5
# Contour area: 48.5
# Contour area: 28.5
# Contour area: 123.0
# Contour area: 94.0
# Contour area: 1555.0
# Contour area: 4.5
# Contour area: 256.5
# Contour area: 0.0
# Contour area: 292.5
# Contour area: 2410.5
# Contour area: 53.5
# Contour area: 12.5
# Contour area: 19.0
# Contour area: 3.0
# Contour area: 74.5
# Contour area: 7.5
# Contour area: 15.5
# Contour area: 173.0
# Contour area: 57.5
# Contour area: 583.0
# Contour area: 11.0
# Contour area: 8.5
# Contour area: 48.0
# Contour area: 17.5
# Contour area: 147.0
# Contour area: 1.5
# Contour area: 36.5
# Contour area: 143.0
# Contour area: 81.0
# Contour area: 105.5
# Contour area: 19.5
# Contour area: 27.5
# Contour area: 4.5
# Contour area: 5.5
# Contour area: 121.0
# Contour area: 0.0
# Contour area: 97.0
# Contour area: 3.0
# Contour area: 105.0
# Contour area: 54.5
# Contour area: 0.0
# Contour area: 61.5
# Contour area: 31.0
# Contour area: 93.5
# Contour area: 767.5
# Contour area: 35.5
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 134.0
# Contour area: 1.0
# Contour area: 167.0
# Contour area: 27.0
# Contour area: 388.0
# Contour area: 34.0
# Contour area: 136.0
# Contour area: 29.5
# Contour area: 9.0
# Contour area: 579.5
# Contour area: 16.5
# Contour area: 8.0
# Contour area: 5.0
# Contour area: 12.0
# Contour area: 26.0
# Contour area: 93.0
# Contour area: 1334.5
# Contour area: 29.0
# Contour area: 14.0
# Contour area: 27.5
# Contour area: 41.0
# Contour area: 73.5
# Contour area: 167.0
# Contour area: 1.0
# Contour area: 363.5
# Contour area: 353.0
# Contour area: 0.0
# Contour area: 7.0
# Contour area: 22.5
# Contour area: 774.5
# Contour area: 3.0
# Contour area: 7.0
# Contour area: 32.5
# Contour area: 133.5
# Contour area: 7.5
# Contour area: 136.5
# Contour area: 22.0
# Contour area: 38.5
# Contour area: 34.5
# Contour area: 218.0
# Contour area: 25.5
# Contour area: 367.0
# Contour area: 10.5
# Contour area: 222.5
# Contour area: 14.5
# Contour area: 1367.5
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 110.5
# Contour area: 132.0
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 54.0
# Contour area: 10.0
# Contour area: 26.5
# Contour area: 174.5
# Contour area: 27.5
# Contour area: 12.5
# Contour area: 2733.5
# Contour area: 1679.5
# Contour area: 31.0
# Contour area: 1.0
# Contour area: 7.5
# Contour area: 97.5
# Contour area: 710.5
# Contour area: 7.5
# Contour area: 22.0
# Contour area: 0.0
# Contour area: 140.5
# Contour area: 1.5
# Contour area: 18.5
# Contour area: 32.5
# Contour area: 22.0
# Contour area: 157.5
# Contour area: 46.5
# Contour area: 276.5
# Contour area: 41.5
# Contour area: 262.5
# Contour area: 188.0
# Contour area: 603.5
# Contour area: 133.0
# Contour area: 465.5
# Contour area: 91.5
# Contour area: 214.0
# Contour area: 2323.5
# Contour area: 7.0
# Contour area: 187.0
# Contour area: 172.0
# Contour area: 255.5
# Contour area: 90.5
# Contour area: 205.5
# Contour area: 1082.5
# Contour area: 1.5
# Contour area: 74.5
# Contour area: 2.0
# Contour area: 2.0
# Contour area: 20.5
# Contour area: 14.5
# Contour area: 171.0
# Contour area: 217.0
# Contour area: 1993.5
# Contour area: 21.5
# Contour area: 125.0
# Contour area: 771.0
# Contour area: 0.0
# Contour area: 73.5
# Contour area: 48.0
# Contour area: 2622.0
# Contour area: 216.0
# Contour area: 19.5
# Contour area: 318.5
# Contour area: 31.0
# Contour area: 1.0
# Contour area: 26.5
# Contour area: 135.5
# Contour area: 140.5
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 29.0
# Contour area: 1996.0
# Contour area: 112.0
# Contour area: 19.5
# Contour area: 4.5
# Contour area: 14.0
# Contour area: 47.5
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 102.5
# Contour area: 0.0
# Contour area: 29.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 2.0
# Contour area: 18.0
# Contour area: 208.5
# Contour area: 377.0
# Contour area: 80.5
# Contour area: 347.5
# Contour area: 109.0
# Contour area: 49.0
# Contour area: 343.0
# Contour area: 0.0
# Contour area: 71.0
# Contour area: 1389.5
# Contour area: 47.5
# Contour area: 2.5
# Contour area: 3.0
# Contour area: 30.0
# Contour area: 255.0
# Contour area: 4.5
# Contour area: 9.5
# Contour area: 214.0
# Contour area: 3.0
# Contour area: 49.0
# Contour area: 1.0
# Contour area: 163.5
# Contour area: 8.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 331.0
# Contour area: 227.5
# Contour area: 1.5
# Contour area: 47.5
# Contour area: 17.0
# Contour area: 389.5
# Contour area: 3515.0
# Contour area: 12.5
# Contour area: 9.5
# Contour area: 5.0
# Contour area: 296.5
# Contour area: 3.5
# Contour area: 140.5
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 299.5
# Contour area: 90.0
# Contour area: 107.0
# Contour area: 68.0
# Contour area: 135.5
# Contour area: 11.5
# Contour area: 751.0
# Contour area: 51.0
# Contour area: 19.5
# Contour area: 75.0
# Contour area: 863.5
# Contour area: 7.0
# Contour area: 0.5
# Contour area: 2.5
# Contour area: 195.5
# Contour area: 45.0
# Contour area: 247.0
# Contour area: 1.0
# Contour area: 36.5
# Contour area: 147.5
# Contour area: 651.0
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 2341.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 147.0
# Contour area: 5.0
# Contour area: 58.5
# Contour area: 74.0
# Contour area: 64.5
# Contour area: 198.0
# Contour area: 18.5
# Contour area: 1354.0
# Contour area: 124.5
# Contour area: 58.0
# Contour area: 54.5
# Contour area: 45.0
# Contour area: 442.0
# Contour area: 264.5
# Contour area: 13.0
# Contour area: 273.0
# Contour area: 1.0
# Contour area: 305.5
# Contour area: 815.5
# Contour area: 92.0
# Contour area: 4.5
# Contour area: 1501.5
# Contour area: 273.0
# Contour area: 145.0
# Contour area: 88.0
# Contour area: 8.5
# Contour area: 177.0
# Contour area: 1666.5
# Contour area: 1.0
# Contour area: 23.5
# Contour area: 17.0
# Contour area: 12.0
# Contour area: 174.5
# Contour area: 33.5
# Contour area: 24.5
# Contour area: 240.5
# Contour area: 9.5
# Contour area: 6872.0
# Contour area: 127.0
# Contour area: 146.0
# Contour area: 874.5
# Contour area: 1026.0
# Contour area: 44.0
# Contour area: 70.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 8.0
# Contour area: 30.5
# Contour area: 31.5
# Contour area: 801.5
# Contour area: 0.5
# Contour area: 3.5
# Contour area: 572.5
# Contour area: 1824.5
# Contour area: 398.0
# Contour area: 6.0
# Contour area: 560.5
# Contour area: 174.5
# Contour area: 8.0
# Contour area: 7.5
# Contour area: 0.0
# Contour area: 90.0
# Contour area: 13.0
# Contour area: 23.5
# Contour area: 0.0
# Contour area: 4.5
# Contour area: 19.5
# Contour area: 1.5
# Contour area: 16.0
# Contour area: 238.5
# Contour area: 6.0
# Contour area: 5.5
# Contour area: 36.0
# Contour area: 242.0
# Contour area: 102.5
# Contour area: 3.0
# Contour area: 116.5
# Contour area: 60.0
# Contour area: 145.5
# Contour area: 109.0
# Contour area: 182.0
# Contour area: 97.0
# Contour area: 273.0
# Contour area: 13.0
# Contour area: 620.5
# Contour area: 48.0
# Contour area: 56.5
# Contour area: 256.0
# Contour area: 2.5
# Contour area: 154.0
# Contour area: 87.0
# Contour area: 281.0
# Contour area: 198.0
# Contour area: 3.0
# Contour area: 9.5
# Contour area: 928.0
# Contour area: 5.0
# Contour area: 679.0
# Contour area: 0.0
# Contour area: 27.0
# Contour area: 1046.5
# Contour area: 13.5
# Contour area: 24.0
# Contour area: 29.5
# Contour area: 3.0
# Contour area: 104.0
# Contour area: 168.0
# Contour area: 209.0
# Contour area: 181.5
# Contour area: 3.0
# Contour area: 2200.0
# Contour area: 59.0
# Contour area: 20.5
# Contour area: 128.0
# Contour area: 109.5
# Contour area: 18.0
# Contour area: 2.5
# Contour area: 5.0
# Contour area: 107.5
# Contour area: 57.5
# Contour area: 3.5
# Contour area: 466.5
# Contour area: 31.0
# Contour area: 1.0
# Contour area: 2.0
# Contour area: 5.0
# Contour area: 703.5
# Contour area: 2.0
# Contour area: 20.5
# Contour area: 1.5
# Contour area: 79.5
# Contour area: 0.0
# Contour area: 17.5
# Contour area: 202.0
# Contour area: 1230.5
# Contour area: 4.0
# Contour area: 12.5
# Contour area: 91.0
# Contour area: 83.0
# Contour area: 161.5
# Contour area: 4.0
# Contour area: 122.5
# Contour area: 0.0
# Contour area: 114.5
# Contour area: 199.5
# Contour area: 5.5
# Contour area: 15.0
# Contour area: 110.5
# Contour area: 3174.0
# Contour area: 326.5
# Contour area: 30.5
# Contour area: 129.0
# Contour area: 1.0
# Contour area: 93.0
# Contour area: 381.5
# Contour area: 55.0
# Contour area: 6.5
# Contour area: 1.5
# Contour area: 15.5
# Contour area: 12.5
# Contour area: 904.5
# Contour area: 34.0
# Contour area: 8.0
# Contour area: 11.0
# Contour area: 233.5
# Contour area: 338.5
# Contour area: 57.5
# Contour area: 28.0
# Contour area: 98.5
# Contour area: 180.0
# Contour area: 156.5
# Contour area: 115.0
# Contour area: 666.0
# Contour area: 67.5
# Contour area: 25.0
# Contour area: 188.0
# Contour area: 14.5
# Contour area: 8.0
# Contour area: 10.0
# Contour area: 24.0
# Contour area: 346.5
# Contour area: 4.5
# Contour area: 182.0
# Contour area: 25.5
# Contour area: 269.0
# Contour area: 2.5
# Contour area: 0.0
# Contour area: 8.5
# Contour area: 231.5
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 259.5
# Contour area: 6147.0
# Contour area: 16.0
# Contour area: 4.5
# Contour area: 5.5
# Contour area: 91.5
# Contour area: 0.0
# Contour area: 2.5
# Contour area: 1202.0
# Contour area: 1.5
# Contour area: 1.0
# Contour area: 28.5
# Contour area: 4564.5
# Contour area: 24.0
# Contour area: 7.0
# Contour area: 22.5
# Contour area: 42.5
# Contour area: 378.0
# Contour area: 21.0
# Contour area: 46.0
# Contour area: 2226.5
# Contour area: 37.0
# Contour area: 207.5
# Contour area: 1.0
# Contour area: 2099.0
# Contour area: 104.5
# Contour area: 74.0
# Contour area: 0.0
# Contour area: 2627.0
# Contour area: 176.5
# Contour area: 133.5
# Contour area: 18.0
# Contour area: 4.0
# Contour area: 11.5
# Contour area: 28.5
# Contour area: 133.5
# Contour area: 0.0
# Contour area: 188.0
# Contour area: 30.0
# Contour area: 43.0
# Contour area: 159.5
# Contour area: 22.5
# Contour area: 108.5
# Contour area: 7.0
# Contour area: 0.0
# Contour area: 811.5
# Contour area: 170.5
# Contour area: 1474.5
# Contour area: 14.0
# Contour area: 345.0
# Contour area: 27.5
# Contour area: 91.5
# Contour area: 5.0
# Contour area: 254.0
# Contour area: 4.0
# Contour area: 21.0
# Contour area: 26.5
# Contour area: 0.0
# Contour area: 37.5
# Contour area: 1909.0
# Contour area: 0.0
# Contour area: 2.0
# Contour area: 50.0
# Contour area: 74.0
# Contour area: 230.0
# Contour area: 290.0
# Contour area: 6.5
# Contour area: 377.5
# Contour area: 159.0
# Contour area: 222.5
# Contour area: 498.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 29.5
# Contour area: 0.0
# Contour area: 232.5
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 167.5
# Contour area: 2.5
# Contour area: 746.5
# Contour area: 13.5
# Contour area: 223.0
# Contour area: 2298.5
# Contour area: 20.0
# Contour area: 1467.0
# Contour area: 281.0
# Contour area: 9.0
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 124.0
# Contour area: 92.5
# Contour area: 169.5
# Contour area: 35.5
# Contour area: 1.0
# Contour area: 0.5
# Contour area: 5.5
# Contour area: 1.0
# Contour area: 48.0
# Contour area: 6.0
# Contour area: 3.5
# Contour area: 33.5
# Contour area: 68.5
# Contour area: 646.0
# Contour area: 1082.0
# Contour area: 2.5
# Contour area: 146.5
# Contour area: 203.0
# Contour area: 69.0
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 1.5
# Contour area: 238.5
# Contour area: 8.5
# Contour area: 0.5
# Contour area: 2.0
# Contour area: 6.0
# Contour area: 715.5
# Contour area: 9.5
# Contour area: 37.0
# Contour area: 150.5
# Contour area: 403.5
# Contour area: 0.0
# Contour area: 32.5
# Contour area: 506.5
# Contour area: 355.5
# Contour area: 452.5
# Contour area: 49.5
# Contour area: 2131.5
# Contour area: 120.0
# Contour area: 703.0
# Contour area: 3.5
# Contour area: 190.0
# Contour area: 0.0
# Contour area: 41.0
# Contour area: 311.0
# Contour area: 132.0
# Contour area: 461.5
# Contour area: 9.0
# Contour area: 43.5
# Contour area: 43.5
# Contour area: 40.5
# Contour area: 12.5
# Contour area: 3.0
# Contour area: 2.5
# Contour area: 17.0
# Contour area: 251.0
# Contour area: 119.0
# Contour area: 0.0
# Contour area: 42.0
# Contour area: 46.5
# Contour area: 1306.5
# Contour area: 163.0
# Contour area: 30.0
# Contour area: 78.0
# Contour area: 10.0
# Contour area: 151.5
# Contour area: 86.5
# Contour area: 2581.0
# Contour area: 175.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 5.5
# Contour area: 227.0
# Contour area: 1540.5
# Contour area: 10.0
# Contour area: 7.5
# Contour area: 57.0
# Contour area: 63.5
# Contour area: 2.0
# Contour area: 20.5
# Contour area: 19.5
# Contour area: 2237.5
# Contour area: 8.0
# Contour area: 21.0
# Contour area: 84.5
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 7.0
# Contour area: 33.5
# Contour area: 17.0
# Contour area: 939.0
# Contour area: 7.0
# Contour area: 1.0
# Contour area: 26.5
# Contour area: 245.0
# Contour area: 24.0
# Contour area: 126.0
# Contour area: 3.0
# Contour area: 192.0
# Contour area: 14.5
# Contour area: 259.0
# Contour area: 2.5
# Contour area: 4.5
# Contour area: 1174.0
# Contour area: 82.0
# Contour area: 907.0
# Contour area: 144.0
# Contour area: 34.5
# Contour area: 0.5
# Contour area: 1.5
# Contour area: 52.5
# Contour area: 207.5
# Contour area: 93.5
# Contour area: 78.0
# Contour area: 5.0
# Contour area: 326.5
# Contour area: 8.5
# Contour area: 42.5
# Contour area: 50.5
# Contour area: 2.5
# Contour area: 1154.0
# Contour area: 247.5
# Contour area: 120.0
# Contour area: 1912.5
# Contour area: 6.0
# Contour area: 43.0
# Contour area: 205.0
# Contour area: 2297.0
# Contour area: 1.5
# Contour area: 79.0
# Contour area: 535.5
# Contour area: 1074.5
# Contour area: 156.5
# Contour area: 86.5
# Contour area: 228.0
# Contour area: 76.5
# Contour area: 239.0
# Contour area: 85.5
# Contour area: 70.5
# Contour area: 2.0
# Contour area: 11.5
# Contour area: 31.0
# Contour area: 255.5
# Contour area: 12.0
# Contour area: 66.5
# Contour area: 26.5
# Contour area: 9.0
# Contour area: 369.0
# Contour area: 596.5
# Contour area: 29.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 20.5
# Contour area: 0.0
# Contour area: 80.0
# Contour area: 4191.0
# Contour area: 208.0
# Contour area: 116.5
# Contour area: 163.0
# Contour area: 164.0
# Contour area: 773.0
# Contour area: 5.0
# Contour area: 106.5
# Contour area: 74.0
# Contour area: 10.0
# Contour area: 97.0
# Contour area: 0.0
# Contour area: 239.0
# Contour area: 4.5
# Contour area: 289.0
# Contour area: 137.5
# Contour area: 408.5
# Contour area: 889.0
# Contour area: 171.0
# Contour area: 105.0
# Contour area: 360.5
# Contour area: 115.0
# Contour area: 290.5
# Contour area: 154.5
# Contour area: 1.0
# Contour area: 78.0
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 9.0
# Contour area: 14.0
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 128.0
# Contour area: 1.5
# Contour area: 1.0
# Contour area: 131.0
# Contour area: 53.5
# Contour area: 73.5
# Contour area: 33.5
# Contour area: 1288.5
# Contour area: 5.5
# Contour area: 38.0
# Contour area: 8.5
# Contour area: 129.0
# Contour area: 79.0
# Contour area: 44.5
# Contour area: 4376.5
# Contour area: 178.0
# Contour area: 314.0
# Contour area: 189.0
# Contour area: 1.0
# Contour area: 4.0
# Contour area: 21.0
# Contour area: 61.0
# Contour area: 1.0
# Contour area: 2.0
# Contour area: 4.5
# Contour area: 0.5
# Contour area: 31.5
# Contour area: 91.0
# Contour area: 5.0
# Contour area: 114.0
# Contour area: 391.0
# Contour area: 0.0
# Contour area: 12.0
# Contour area: 149.0
# Contour area: 167.5
# Contour area: 12.0
# Contour area: 79.0
# Contour area: 17.5
# Contour area: 886.5
# Contour area: 10.5
# Contour area: 168.0
# Contour area: 135.0
# Contour area: 89.5
# Contour area: 55.5
# Contour area: 29.0
# Contour area: 1913.5
# Contour area: 342.5
# Contour area: 192.0
# Contour area: 7.5
# Contour area: 76.0
# Contour area: 129.0
# Contour area: 49.5
# Contour area: 276.5
# Contour area: 0.0
# Contour area: 100.0
# Contour area: 5.0
# Contour area: 3019.5
# Contour area: 90.5
# Contour area: 160.0
# Contour area: 25.0
# Contour area: 509.5
# Contour area: 15.0
# Contour area: 3.0
# Contour area: 202.0
# Contour area: 25.0
# Contour area: 35.5
# Contour area: 23.5
# Contour area: 1.5
# Contour area: 17.0
# Contour area: 1474.5
# Contour area: 86.5
# Contour area: 206.0
# Contour area: 0.5
# Contour area: 31.5
# Contour area: 0.5
# Contour area: 228.5
# Contour area: 8.0
# Contour area: 273.5
# Contour area: 25.0
# Contour area: 3.0
# Contour area: 1283.5
# Contour area: 13.0
# Contour area: 0.0
# Contour area: 235.5
# Contour area: 10.5
# Contour area: 42.0
# Contour area: 506.0
# Contour area: 846.0
# Contour area: 8.0
# Contour area: 8.0
# Contour area: 739.0
# Contour area: 57.5
# Contour area: 918.5
# Contour area: 14.5
# Contour area: 18.0
# Contour area: 4.5
# Contour area: 2.5
# Contour area: 0.0
# Contour area: 11.5
# Contour area: 1.0
# Contour area: 97.0
# Contour area: 1750.5
# Contour area: 12.5
# Contour area: 83.0
# Contour area: 498.0
# Contour area: 86.0
# Contour area: 9.0
# Contour area: 146.5
# Contour area: 100.0
# Contour area: 1.5
# Contour area: 3.0
# Contour area: 176.0
# Contour area: 87.0
# Contour area: 70.5
# Contour area: 271.5
# Contour area: 3.5
# Contour area: 70.0
# Contour area: 2.0
# Contour area: 12.5
# Contour area: 187.0
# Contour area: 1.0
# Contour area: 38.5
# Contour area: 95.5
# Contour area: 9.0
# Contour area: 373.0
# Contour area: 136.0
# Contour area: 16.0
# Contour area: 315.5
# Contour area: 405.5
# Contour area: 19.5
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 54.0
# Contour area: 264.5
# Contour area: 26.5
# Contour area: 116.0
# Contour area: 1629.5
# Contour area: 4.0
# Contour area: 20.0
# Contour area: 220.0
# Contour area: 5.0
# Contour area: 29.0
# Contour area: 42.0
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 453.5
# Contour area: 1027.0
# Contour area: 1.0
# Contour area: 134.5
# Contour area: 98.0
# Contour area: 279.5
# Contour area: 161.0
# Contour area: 1.5
# Contour area: 3.5
# Contour area: 119.0
# Contour area: 0.0
# Contour area: 49.0
# Contour area: 188.5
# Contour area: 49.5
# Contour area: 550.0
# Contour area: 33.0
# Contour area: 15.5
# Contour area: 6.5
# Contour area: 40.5
# Contour area: 135.0
# Contour area: 62.0
# Contour area: 13.5
# Contour area: 42.0
# Contour area: 23.0
# Contour area: 22.0
# Contour area: 0.0
# Contour area: 58.5
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 1.5
# Contour area: 22.5
# Contour area: 20.0
# Contour area: 1.0
# Contour area: 21.0
# Contour area: 392.5
# Contour area: 19.5
# Contour area: 73.5
# Contour area: 24.5
# Contour area: 245.0
# Contour area: 290.0
# Contour area: 85.5
# Contour area: 88.5
# Contour area: 110.0
# Contour area: 65.0
# Contour area: 106.5
# Contour area: 7.0
# Contour area: 1.5
# Contour area: 1.5
# Contour area: 218.5
# Contour area: 3.0
# Contour area: 101.0
# Contour area: 2.0
# Contour area: 346.0
# Contour area: 97.0
# Contour area: 9.0
# Contour area: 1.5
# Contour area: 31.5
# Contour area: 36.5
# Contour area: 8.0
# Contour area: 7.0
# Contour area: 47.5
# Contour area: 1216.0
# Contour area: 107.5
# Contour area: 1.5
# Contour area: 14.0
# Contour area: 22.5
# Contour area: 186.0
# Contour area: 797.5
# Contour area: 23.5
# Contour area: 61.5
# Contour area: 17.5
# Contour area: 339.0
# Contour area: 15.5
# Contour area: 578.5
# Contour area: 2.0
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 27.0
# Contour area: 30.5
# Contour area: 11.0
# Contour area: 7.0
# Contour area: 80.5
# Contour area: 11.5
# Contour area: 12.5
# Contour area: 702.0
# Contour area: 2935.5
# Contour area: 20.5
# Contour area: 1752.5
# Contour area: 597.0
# Contour area: 5.0
# Contour area: 77.5
# Contour area: 1920.5
# Contour area: 102.5
# Contour area: 117.5
# Contour area: 4.5
# Contour area: 1701.0
# Contour area: 286.0
# Contour area: 87.5
# Contour area: 1805.5
# Contour area: 10.0
# Contour area: 1002.0
# Contour area: 48.5
# Contour area: 727.5
# Contour area: 119.0
# Contour area: 25.5
# Contour area: 264.5
# Contour area: 2.0
# Contour area: 419.5
# Contour area: 1.0
# Contour area: 378.0
# Contour area: 17.5
# Contour area: 99.5
# Contour area: 18.0
# Contour area: 118.0
# Contour area: 159.5
# Contour area: 0.0
# Contour area: 8.0
# Contour area: 11.0
# Contour area: 101.5
# Contour area: 1396.5
# Contour area: 4.5
# Contour area: 143.0
# Contour area: 0.0
# Contour area: 180.5
# Contour area: 22.0
# Contour area: 104.0
# Contour area: 76.0
# Contour area: 5.0
# Contour area: 6.0
# Contour area: 310.0
# Contour area: 278.0
# Contour area: 1647.5
# Contour area: 25.0
# Contour area: 24.5
# Contour area: 7.0
# Contour area: 30.5
# Contour area: 51.5
# Contour area: 5.0
# Contour area: 3.5
# Contour area: 6.0
# Contour area: 102.0
# Contour area: 7.5
# Contour area: 7.5
# Contour area: 21.0
# Contour area: 27.5
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 265.5
# Contour area: 37.0
# Contour area: 45.5
# Contour area: 10.0
# Contour area: 1.5
# Contour area: 242.5
# Contour area: 7.0
# Contour area: 11.5
# Contour area: 16.5
# Contour area: 112.5
# Contour area: 18.0
# Contour area: 907.5
# Contour area: 46.0
# Contour area: 436.0
# Contour area: 60.0
# Contour area: 3.0
# Contour area: 20.5
# Contour area: 811.5
# Contour area: 0.5
# Contour area: 823.0
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 2309.5
# Contour area: 10.5
# Contour area: 57.0
# Contour area: 10.5
# Contour area: 55.0
# Contour area: 0.0
# Contour area: 2.5
# Contour area: 92.5
# Contour area: 55.0
# Contour area: 3.5
# Contour area: 56.0
# Contour area: 74.5
# Contour area: 12.0
# Contour area: 5.5
# Contour area: 91.0
# Contour area: 144.0
# Contour area: 34.0
# Contour area: 11.5
# Contour area: 266.5
# Contour area: 133.5
# Contour area: 2.5
# Contour area: 0.0
# Contour area: 44.5
# Contour area: 2.0
# Contour area: 155.5
# Contour area: 191.5
# Contour area: 1.0
# Contour area: 40.5
# Contour area: 3916.5
# Contour area: 9.0
# Contour area: 7.5
# Contour area: 0.0
# Contour area: 878.0
# Contour area: 1236.5
# Contour area: 245.5
# Contour area: 27.0
# Contour area: 42.0
# Contour area: 147.5
# Contour area: 31.5
# Contour area: 27.5
# Contour area: 980.0
# Contour area: 1258.0
# Contour area: 32.0
# Contour area: 2.5
# Contour area: 229.0
# Contour area: 231.0
# Contour area: 1361.5
# Contour area: 193.5
# Contour area: 44.5
# Contour area: 121.0
# Contour area: 1509.0
# Contour area: 70.0
# Contour area: 888.0
# Contour area: 0.5
# Contour area: 189.0
# Contour area: 22.0
# Contour area: 3.0
# Contour area: 137.5
# Contour area: 0.0
# Contour area: 274.0
# Contour area: 171.0
# Contour area: 367.0
# Contour area: 320.0
# Contour area: 7.0
# Contour area: 52.5
# Contour area: 173.5
# Contour area: 140.5
# Contour area: 984.0
# Contour area: 47.0
# Contour area: 0.0
# Contour area: 36.0
# Contour area: 1.5
# Contour area: 6.0
# Contour area: 2.0
# Contour area: 6.0
# Contour area: 277.0
# Contour area: 30.0
# Contour area: 13.5
# Contour area: 13.5
# Contour area: 618.0
# Contour area: 989.0
# Contour area: 784.0
# Contour area: 48.0
# Contour area: 120.0
# Contour area: 27.0
# ...
# Contour area: 4.5
# Contour area: 3.0
# Contour area: 18.0
# Contour area: 9.0
# Contour area: 8.5
# Contour area: 1.0
# Contour area: 81.0
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 5.5
# Contour area: 245.0
# Contour area: 8.5
# Contour area: 0.0
# Contour area: 72.5
# Contour area: 19.5
# Contour area: 1.0
# Contour area: 26.0
# Contour area: 0.5
# Contour area: 13.5
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 9.5
# Contour area: 9.5
# Contour area: 30.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 73.0
# Contour area: 8.5
# Contour area: 3.0
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 9.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 4.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 8.0
# Contour area: 40.5
# Contour area: 77.0
# Contour area: 2.0
# Contour area: 82.0
# Contour area: 5.5
# Contour area: 21.5
# Contour area: 6.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 21.0
# Contour area: 122.0
# Contour area: 23.5
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 6.0
# Contour area: 10.0
# Contour area: 2.5
# Contour area: 0.0
# Contour area: 121.0
# Contour area: 156.0
# Contour area: 12.5
# Contour area: 4.0
# Contour area: 28.5
# Contour area: 6.5
# Contour area: 12.5
# Contour area: 0.0
# Contour area: 314.5
# Contour area: 12.5
# Contour area: 17.0
# Contour area: 0.5
# Contour area: 1.0
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 435.0
# Contour area: 4.5
# Contour area: 0.0
# Contour area: 8.5
# Contour area: 0.0
# Contour area: 321.5
# Contour area: 0.0
# Contour area: 26.0
# Contour area: 16.5
# Contour area: 49.0
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 18.0
# Contour area: 6.0
# Contour area: 33.5
# Contour area: 5.0
# Contour area: 2.5
# Contour area: 102.5
# Contour area: 0.0
# Contour area: 14.0
# Contour area: 29.5
# Contour area: 7.0
# Contour area: 0.0
# Contour area: 22.0
# Contour area: 51.0
# Contour area: 26.5
# Contour area: 0.0
# Contour area: 10.0
# Contour area: 10.5
# Contour area: 40.0
# Contour area: 615.0
# Contour area: 2.0
# Contour area: 15.5
# Contour area: 16.0
# Contour area: 3.0
# Contour area: 3.5
# Contour area: 71.0
# Contour area: 72.5
# Contour area: 21.0
# Contour area: 16.0
# Contour area: 5.5
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 6.0
# Contour area: 184.5
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 406.5
# Contour area: 12.5
# Contour area: 5.0
# Contour area: 29.5
# Contour area: 44.5
# Contour area: 10.5
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 13.5
# Contour area: 344.0
# Contour area: 6.0
# Contour area: 3.5
# Contour area: 10605.0
# Contour area: 5.0
# Contour area: 7.5
# Contour area: 10.0
# Contour area: 8.5
# Contour area: 0.0
# Contour area: 4.5
# Contour area: 14.5
# Contour area: 10.5
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 45.5
# Contour area: 28.5
# Contour area: 2.0
# Contour area: 5.0
# Contour area: 21.0
# Contour area: 3.0
# Contour area: 118.5
# Contour area: 495.0
# Contour area: 0.0
# Contour area: 97.5
# Contour area: 1.5
# Contour area: 34.0
# Contour area: 37.5
# Contour area: 14.0
# Contour area: 3.0
# Contour area: 18.0
# Contour area: 1.0
# Contour area: 115.5
# Contour area: 106.5
# Contour area: 37.0
# Contour area: 8.0
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 18.0
# Contour area: 53.5
# Contour area: 67.5
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 13.0
# Contour area: 6.0
# Contour area: 8.5
# Contour area: 41.0
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 202.5
# Contour area: 2.0
# Contour area: 6.5
# Contour area: 1503.0
# Contour area: 3.5
# Contour area: 2.0
# Contour area: 105.0
# Contour area: 4.0
# Contour area: 10.5
# Contour area: 21.5
# Contour area: 11.5
# Contour area: 4.0
# Contour area: 10.0
# Contour area: 6.0
# Contour area: 7.5
# Contour area: 5.5
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 21.0
# Contour area: 7.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 43.5
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 37.5
# Contour area: 28.0
# Contour area: 4.0
# Contour area: 3.5
# Contour area: 4.0
# Contour area: 8.0
# Contour area: 15.5
# Contour area: 165.0
# Contour area: 9.0
# Contour area: 45.0
# Contour area: 10.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 56.0
# Contour area: 62.5
# Contour area: 3.0
# Contour area: 0.0
# Contour area: 7.0
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 17.0
# Contour area: 5.0
# Contour area: 65.5
# Contour area: 3.0
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 19.5
# Contour area: 0.0
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 8.0
# Contour area: 32.0
# Contour area: 0.0
# Contour area: 13.5
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 5.5
# Contour area: 432.5
# Contour area: 0.0
# Contour area: 10.0
# Contour area: 4.5
# Contour area: 3.0
# Contour area: 18.5
# Contour area: 0.5
# Contour area: 6.5
# Contour area: 12.0
# Contour area: 5.0
# Contour area: 2.0
# Contour area: 0.0
# Contour area: 104.5
# Contour area: 126.5
# Contour area: 0.5
# Contour area: 49.5
# Contour area: 35.5
# Contour area: 1.5
# Contour area: 2.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 13.5
# Contour area: 14.5
# Contour area: 18.0
# Contour area: 22.0
# Contour area: 0.0
# Contour area: 42.0
# Contour area: 2.0
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 8.0
# Contour area: 17.0
# Contour area: 0.0
# Contour area: 33.5
# Contour area: 27.5
# Contour area: 2.5
# Contour area: 8.5
# Contour area: 48.5
# Contour area: 7.0
# Contour area: 0.0
# Contour area: 17.0
# Contour area: 1.5
# Contour area: 153.0
# Contour area: 41.0
# Contour area: 654.0
# Contour area: 21.0
# Contour area: 10.5
# Contour area: 45.5
# Contour area: 8.0
# Contour area: 0.5
# Contour area: 8.0
# Contour area: 1.0
# Contour area: 5.0
# Contour area: 6.0
# Contour area: 25.5
# Contour area: 4.5
# Contour area: 2.0
# Contour area: 466.5
# Contour area: 0.0
# Contour area: 21.0
# Contour area: 21.0
# Contour area: 60.5
# Contour area: 3.0
# Contour area: 16.5
# Contour area: 0.0
# Contour area: 46.5
# Contour area: 6.5
# Contour area: 5.0
# Contour area: 3.0
# Contour area: 3.5
# Contour area: 5.5
# Contour area: 0.0
# Contour area: 17.0
# Contour area: 2.0
# Contour area: 33.5
# Contour area: 1.5
# Contour area: 1.0
# Contour area: 106.0
# Contour area: 74.0
# Contour area: 17.5
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 13.5
# Contour area: 300.0
# Contour area: 0.0
# Contour area: 14.5
# Contour area: 12.0
# Contour area: 0.0
# Contour area: 905.5
# Contour area: 10.5
# Contour area: 4.5
# Contour area: 20.0
# Contour area: 0.5
# Contour area: 5.5
# Contour area: 1.5
# Contour area: 5.5
# Contour area: 0.0
# Contour area: 77.5
# Contour area: 14.5
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 11.5
# Contour area: 3.5
# Contour area: 2.0
# Contour area: 1010.5
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 21.0
# Contour area: 41.0
# Contour area: 198.0
# Contour area: 1.5
# Contour area: 16.5
# Contour area: 2.0
# Contour area: 6.5
# Contour area: 0.5
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 11.5
# Contour area: 1.0
# Contour area: 3.0
# Contour area: 15.5
# Contour area: 27.5
# Contour area: 39.5
# Contour area: 95.5
# Contour area: 52.5
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 2.0
# Contour area: 245.0
# Contour area: 0.0
# Contour area: 12.0
# Contour area: 2.0
# Contour area: 24.5
# Contour area: 25.5
# Contour area: 10.0
# Contour area: 105.5
# Contour area: 0.5
# Contour area: 38.0
# Contour area: 0.5
# Contour area: 4.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 7.5
# Contour area: 8.5
# Contour area: 3.0
# Contour area: 4.0
# Contour area: 37.0
# Contour area: 61.5
# Contour area: 27.0
# Contour area: 5.0
# Contour area: 6.0
# Contour area: 2.0
# Contour area: 0.5
# Contour area: 159.5
# Contour area: 45.5
# Contour area: 28.0
# Contour area: 12.5
# Contour area: 4.5
# Contour area: 49.5
# Contour area: 13.0
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 4.0
# Contour area: 2.0
# Contour area: 106.5
# Contour area: 0.5
# Contour area: 13.0
# Contour area: 10.5
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 306.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 6.5
# Contour area: 0.5
# Contour area: 11.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 21.5
# Contour area: 0.0
# Contour area: 162.0
# Contour area: 12.0
# Contour area: 31.0
# Contour area: 36.0
# Contour area: 66.0
# Contour area: 3.5
# Contour area: 12.5
# Contour area: 27.0
# Contour area: 0.0
# Contour area: 125.0
# Contour area: 10.5
# Contour area: 16.5
# Contour area: 2.0
# Contour area: 13.5
# Contour area: 3.0
# Contour area: 15.5
# Contour area: 236.5
# Contour area: 36.0
# Contour area: 4.5
# Contour area: 0.0
# Contour area: 6.0
# Contour area: 0.5
# Contour area: 0.0
# Contour area: 2.5
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 40.0
# Contour area: 9.5
# Contour area: 9.5
# Contour area: 528.5
# Contour area: 42.0
# Contour area: 3.0
# Contour area: 10.5
# Contour area: 31.0
# Contour area: 49.5
# Contour area: 11.0
# Contour area: 10.0
# Contour area: 10.5
# Contour area: 3.0
# Contour area: 6.0
# Contour area: 6.5
# Contour area: 0.0
# Contour area: 78.5
# Contour area: 5.0
# Contour area: 78.0
# Contour area: 7.0
# Contour area: 0.5
# Contour area: 6.5
# Contour area: 0.5
# Contour area: 46.5
# Contour area: 39.5
# Contour area: 0.0
# Contour area: 3.0
# Contour area: 17.0
# Contour area: 23.0
# Contour area: 5.5
# Contour area: 63.5
# Contour area: 39.5
# Contour area: 0.0
# Contour area: 2.5
# Contour area: 13.5
# Contour area: 6.5
# Contour area: 11.0
# Contour area: 141.0
# Contour area: 0.5
# Contour area: 62.0
# Contour area: 1.0
# Contour area: 7.0
# Contour area: 46.0
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 297.5
# Contour area: 8.5
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 85.0
# Contour area: 95.5
# Contour area: 59.5
# Contour area: 0.5
# Contour area: 3.5
# Contour area: 2.5
# Contour area: 0.5
# Contour area: 23.5
# Contour area: 3.0
# Contour area: 11.0
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 31.0
# Contour area: 3.5
# Contour area: 17.0
# Contour area: 0.0
# Contour area: 32.5
# Contour area: 9.5
# Contour area: 1.0
# Contour area: 125.5
# Contour area: 25.5
# Contour area: 18.0
# Contour area: 38.0
# Contour area: 3.0
# Contour area: 11.5
# Contour area: 3.5
# Contour area: 107.5
# Contour area: 68.5
# Contour area: 1.5
# Contour area: 0.0
# Contour area: 54.5
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 0.0
# Contour area: 12.0
# Contour area: 3.5
# Contour area: 4.0
# Contour area: 11.5
# Contour area: 9.0
# Contour area: 21.0
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 19.0
# Contour area: 5.0
# Contour area: 57.5
# Contour area: 44.0
# Contour area: 1.0
# Contour area: 0.5
# Contour area: 17.5
# Contour area: 413.5
# Contour area: 22.5
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 0.5
# Contour area: 168.0
# Contour area: 3.0
# Contour area: 4.0
# Contour area: 5.0
# Contour area: 34.5
# Contour area: 6.0
# Contour area: 46.5
# Contour area: 5.0
# Contour area: 26.5
# Contour area: 0.0
# Contour area: 3.0
# Contour area: 0.0
# Contour area: 12.5
# Contour area: 0.0
# Contour area: 16.0
# Contour area: 29.0
# Contour area: 3.0
# Contour area: 837.5
# Contour area: 93.5
# Contour area: 16.5
# Contour area: 28.5
# Contour area: 18.0
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 81.0
# Contour area: 0.0
# Contour area: 59.5
# Contour area: 93.5
# Contour area: 1.5
# Contour area: 10.0
# Contour area: 59.5
# Contour area: 2.0
# Contour area: 131.5
# Contour area: 125.5
# Contour area: 124.0
# Contour area: 1.5
# Contour area: 8.5
# Contour area: 6.5
# Contour area: 13.0
# Contour area: 6.0
# Contour area: 3.5
# Contour area: 0.0
# Contour area: 5.0
# Contour area: 2.0
# Contour area: 44.5
# Contour area: 7.5
# Contour area: 83.0
# Contour area: 32.5
# Contour area: 77.5
# Contour area: 11.5
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 1.5
# Contour area: 34.0
# Contour area: 8.0
# Contour area: 0.0
# Contour area: 4.5
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 35.0
# Contour area: 10.5
# Contour area: 3.5
# Contour area: 6.5
# Contour area: 65.0
# Contour area: 0.0
# Contour area: 7.0
# Contour area: 0.0
# Contour area: 15.0
# Contour area: 0.0
# Contour area: 99.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 16.0
# Contour area: 6.5
# Contour area: 5.0
# Contour area: 186.0
# Contour area: 20.0
# Contour area: 667.0
# Contour area: 1.0
# Contour area: 6.0
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 10.0
# Contour area: 24.0
# Contour area: 4.0
# Contour area: 20.0
# Contour area: 0.0
# Contour area: 335.5
# Contour area: 0.0
# Contour area: 26.5
# Contour area: 70.0
# Contour area: 12.5
# Contour area: 12.0
# Contour area: 6.0
# Contour area: 14.0
# Contour area: 1.5
# Contour area: 5.5
# Contour area: 34.5
# Contour area: 35.0
# Contour area: 55.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 14.5
# Contour area: 30.5
# Contour area: 1.0
# Contour area: 3.5
# Contour area: 2.0
# Contour area: 11.0
# Contour area: 0.5
# Contour area: 110.5
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 3.5
# Contour area: 191.0
# Contour area: 8.0
# Contour area: 0.0
# Contour area: 294894.5
# Contour area: 37.5
# Contour area: 1.0
# Contour area: 0.0
# Contour area: 1.5
# Contour area: 24.0
# Contour area: 48.5
# Contour area: 3.0
# Contour area: 12.0
# Contour area: 305.0
# Contour area: 336.5
# Contour area: 69.0
# Contour area: 1.0
# Contour area: 4.0
# Contour area: 7.0
# Contour area: 21.5
# Contour area: 1.0
# Contour area: 21.0
# Contour area: 15.5
# Contour area: 4.0
# Contour area: 117.5
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 632.0
# Contour area: 1.5
# Contour area: 5.5
# Contour area: 0.0
# Contour area: 6.5
# Contour area: 3.0
# Contour area: 10.5
# Contour area: 1.5
# Contour area: 3.5
# Contour area: 9.0
# Contour area: 3.0
# Contour area: 21.0
# Contour area: 3.5
# Contour area: 11.0
# Contour area: 35.0
# Contour area: 33.5
# Contour area: 17.0
# Contour area: 0.5
# Contour area: 2.0
# Contour area: 15.5
# Contour area: 0.5
# Contour area: 2.0
# Contour area: 31.5
# Contour area: 46.0
# Contour area: 0.0
# Contour area: 1.0
# Contour area: 13.0
# Contour area: 5.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 4.0
# Contour area: 4.5
# Contour area: 45.5
# Contour area: 2.5
# Contour area: 22.5
# Contour area: 0.5
# Contour area: 6.0
# Contour area: 0.0
# Contour area: 0.0
# Contour area: 62.5
# Contour area: 7.5
# Contour area: 13.0
# Contour area: 517.0
# Contour area: 203.0
# Contour area: 20.0
# Contour area: 876.5
# Contour area: 2.0
# Contour area: 0.5
# Contour area: 5.5
# Contour area: 532.0
# Contour area: 1.0
# Contour area: 7.5
# Contour area: 122.0
# Contour area: 126.0
# Contour area: 3.0
# Contour area: 29.0
# Contour area: 0.0
# Contour area: 390.0
# Contour area: 14.0
# Contour area: 67.5
# Contour area: 395.5
# Contour area: 326.5
# Contour area: 110.0
# Contour area: 16.5
# Contour area: 199.0
# Contour area: 52.5
# Contour area: 12.5
# Contour area: 1746.5
# Contour area: 473.0
# Contour area: 27.5
# Contour area: 219.5
# Contour area: 11.5
# Contour area: 2187.5
# Contour area: 16.0
# Contour area: 2.5
# Contour area: 265.0
# Contour area: 0.0
# Contour area: 7.0
# Contour area: 4.0
# Contour area: 5.5
# Contour area: 142.0
# Contour area: 152.0
# Contour area: 5.5
# Contour area: 242.0
# Contour area: 356.5
# Contour area: 70.5
# Contour area: 238.5
# Contour area: 5.5
# Contour area: 1.5
# Contour area: 853.0
# Contour area: 465.5
# Contour area: 615.0
# Contour area: 729.5
# Contour area: 26.5
# Contour area: 14.0
# Contour area: 4.0
# Contour area: 255.0
# Contour area: 128.0
# Contour area: 30.0
# Contour area: 6.0
# Contour area: 29.5
# Contour area: 38.5
# Contour area: 1.5
# Contour area: 5.5
# Contour area: 151.5
# Contour area: 2.0
# Contour area: 1.5
# Contour area: 56.0
# Contour area: 2.0
# Contour area: 27.0
# Contour area: 2.5
# Contour area: 1.5
# Contour area: 14352.5
# Contour area: 0.0
# Contour area: 127.0
# Contour area: 12.0
# Contour area: 14.5
# Contour area: 31.0
# Contour area: 163.5
# Contour area: 0.5
# Contour area: 73.0
# Contour area: 17.5
# Contour area: 161.5
# Contour area: 266.5
# Contour area: 4.5
# Contour area: 8.0
# Contour area: 5.5
# Contour area: 59.5
# Contour area: 6.5
# Contour area: 0.5
# Contour area: 6.0
# Contour area: 1.0
# Contour area: 1.0
# Contour area: 6.0
# Old largest area: 0
# New largest contour with area: 25713.0
# Old largest area: 25713.0
# New largest contour with area: 153504.5
# Old largest area: 153504.5
# New largest contour with area: 1845724.5
# [[[1772 1022]]
#
#  [[1771 1023]]
#
#  [[1771 1024]]
#
#  ...
#
#  [[1775 1023]]
#
#  [[1774 1023]]
#
#  [[1773 1022]]]
# (1578.61279296875, 1863.771728515625)
# [[ 829.77655 1102.4839 ]
#  [2100.0532   931.8841 ]
#  [2327.449   2625.0596 ]
#  [1057.1724  2795.6594 ]]

# %%
drawnImage = img.copy()
img_with_contours = cv2.drawContours(drawnImage, filtered, -1, (0, 255, 0), 2)
plt.imshow(img_with_contours)
plt.show()

x, y, w, h = cv2.boundingRect(filtered[0])
cropped_img = img[y:y+h, x:x+w]
plt.imshow(cropped_img)
plt.show()

# %%
angle = rect[2]

if angle < -45:
    angle = (90 + angle)

# otherwise, just take the inverse of the angle to make
# it positive
else:
    angle = -angle  

# rotate the image to deskew it
(h, w) = img.shape[:2]
center = (w // 2, h // 2)
M = cv2.getRotationMatrix2D(center, angle, 1.0)
rotated = cv2.warpAffine(img, M, (w, h),flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE) 
plt.imshow(M)
